# %%
pip install pandas numpy seaborn matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\melvin\appdata\local\programs\python\python310\lib\site-packages (2.2.3)Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.0.1 is available.
# You should consider upgrading via the 'c:\Users\melvin\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: numpy in c:\users\melvin\appdata\local\programs\python\python310\lib\site-packages (2.2.3)
# Requirement already satisfied: seaborn in c:\users\melvin\appdata\local\programs\python\python310\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\melvin\appdata\local\programs\python\python310\lib\site-packages (3.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\melvin\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\melvin\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\melvin\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\melvin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\melvin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\melvin\appdata\roaming\python\python310\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\melvin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: pillow>=8 in c:\users\melvin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\melvin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\melvin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: six>=1.5 in c:\users\melvin\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Creating a sample dataset
data = {
    "CustomerID": range(1, 21),
    "Gender": np.random.choice(["Male", "Female"], size=20),
    "SeniorCitizen": np.random.choice([0, 1], size=20),  # 0 = Not senior, 1 = Senior
    "Contract": np.random.choice(["Month-to-month", "One year", "Two year"], size=20),
    "PaymentMethod": np.random.choice(["Electronic check", "Mailed check", "Bank transfer", "Credit card"], size=20),
    "InternetService": np.random.choice(["DSL", "Fiber optic", "No"], size=20),
    "State": np.random.choice(["California", "Texas", "New York", "Florida"], size=20),
    "Churn": np.random.choice(["Yes", "No"], size=20, p=[0.3, 0.7])  # Imbalanced churn
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Display basic dataset info
print("\nDataset Overview:")
print(df.info())

# Show first few rows
print("\nSample Data:")
print(df.head())

# Check class imbalance in target variable
print("\nChurn Distribution:")
print(df["Churn"].value_counts(normalize=True))

# Plot churn distribution
sns.countplot(data=df, x="Churn")
plt.title("Churn Class Distribution")
plt.show()

# Function to detect imbalance in categorical features
def detect_bias(column):
    print(f"\n### Analyzing Bias in {column} ###")
    churn_counts = df.groupby(column)["Churn"].value_counts(normalize=True).unstack()
    print(churn_counts)

    # Plot churn rate by category
    plt.figure(figsize=(6, 4))
    sns.barplot(x=column, y=df["Churn"].apply(lambda x: 1 if x == "Yes" else 0), data=df)
    plt.title(f"Churn Rate by {column}")
    plt.xticks(rotation=30)
    plt.show()

# List of columns to check for bias
bias_columns = ["Gender", "SeniorCitizen", "Contract", "PaymentMethod", "InternetService", "State"]

# Analyze bias in each column
for col in bias_columns:
    if col in df.columns:
        detect_bias(col)

# Missing values analysis
missing_values = df.isnull().sum()
print("\nMissing Values per Column:")
print(missing_values[missing_values > 0])
# Out:
# Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       20 non-null     int64
#  1   Gender           20 non-null     object
#  2   SeniorCitizen    20 non-null     int64
#  3   Contract         20 non-null     object
#  4   PaymentMethod    20 non-null     object
#  5   InternetService  20 non-null     object
#  6   State            20 non-null     object
#  7   Churn            20 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 1.4+ KB
# None
#
# Sample Data:
#    CustomerID  Gender  SeniorCitizen        Contract     PaymentMethod  \
# 0           1    Male              1        Two year  Electronic check
# 1           2    Male              0  Month-to-month     Bank transfer
# 2           3  Female              1        One year       Credit card
# 3           4    Male              1        Two year       Credit card
# 4           5  Female              1        One year  Electronic check
#
#   InternetService       State Churn
# 0             DSL  California   Yes
# 1             DSL  California    No
# 2              No       Texas   Yes
# 3              No  California    No
# 4              No    New York    No
#
# Churn Distribution:
# Churn
# No     0.7
# Yes    0.3
# Name: proportion, dtype: float64
# ### Analyzing Bias in Gender ###
# Churn         No       Yes
# Gender
# Female  0.714286  0.285714
# Male    0.666667  0.333333
# ### Analyzing Bias in SeniorCitizen ###
# Churn                No       Yes
# SeniorCitizen
# 0              0.888889  0.111111
# 1              0.545455  0.454545
# ### Analyzing Bias in Contract ###
# Churn            No  Yes
# Contract
# Month-to-month  1.0  NaN
# One year        0.5  0.5
# Two year        0.4  0.6
# ### Analyzing Bias in PaymentMethod ###
# Churn                   No       Yes
# PaymentMethod
# Bank transfer     0.750000  0.250000
# Credit card       0.666667  0.333333
# Electronic check  0.500000  0.500000
# Mailed check      0.857143  0.142857
# ### Analyzing Bias in InternetService ###
# Churn                  No       Yes
# InternetService
# DSL              0.857143  0.142857
# Fiber optic      0.600000  0.400000
# No               0.625000  0.375000
# ### Analyzing Bias in State ###
# Churn             No       Yes
# State
# California  0.857143  0.142857
# Florida     0.600000  0.400000
# New York    1.000000       NaN
# Texas       0.250000  0.750000
# Missing Values per Column:
# Series([], dtype: int64)
